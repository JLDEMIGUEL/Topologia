# %% [markdown]
# # Ejemplos Persistencia

# %%
from pathlib import Path
import os
import sys
sys.path.append(os.path.dirname(Path(os.getcwd()).parent.parent))
import json
import numpy as np
from ComplejosSimpliciales.src.AlphaComplex import AlphaComplex
from ComplejosSimpliciales.src.utils.simplicial_complex_utils import noise
from ComplejosSimpliciales.src.VietorisRipsComplex import Vietoris_RipsComplex
CLOUD_PATH = os.path.join(os.path.dirname(Path(os.getcwd()).parent.parent),"docs","clouds.json")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Ejemplo 1

# %%
alpha = AlphaComplex([[-3, 0], [0, 1], [3, 0], [-1.7, -1.8], [1.7, -1.8], [0, -4]])
alpha.plotalpha()
alpha.persistence_diagram()
alpha.barcode_diagram()

# %% [markdown]
# ### Ejemplo 2 - FIGURA OCHO

# %%
points = json.load(open(CLOUD_PATH))['eight']
alpha = AlphaComplex(np.array(noise(points)))
#alpha.plotalpha()
alpha.persistence_diagram()
alpha.barcode_diagram()

# %% [markdown]
# ### Ejemplo 3 - ROSA 3 PETALOS

# %%
points = json.load(open(CLOUD_PATH))['3-petal']
alpha = AlphaComplex(np.array(noise(points)))
#alpha.plotalpha()
alpha.persistence_diagram()
alpha.barcode_diagram()

# %% [markdown]
# ### Ejemplo 4 - VIETORIS RIPS

# %%
alpha = Vietoris_RipsComplex([[-3, 0], [0, 1], [3, 0], [-1.7, -1.8], [1.7, -1.8], [0, -4]])
alpha.persistence_diagram()
alpha.barcode_diagram()
