# %% [markdown]
# # Ejemplos Alpha Complejos

# %%
# %load_ext autoreload
# %autoreload 2

import os
import json
from pathlib import Path
import numpy as np
import sys
sys.path.append(os.path.dirname(Path(os.getcwd()).parent))
from SimplicialComplex.AlphaComplex import AlphaComplex
from SimplicialComplex.utils.simplicial_complex_utils import noise
CLOUD_PATH = os.path.join(os.path.dirname(Path(os.getcwd()).parent),"docs","clouds.json")

# %% [markdown]
# ### Ejemplo 1

# %%
points = json.load(open(CLOUD_PATH))['alpha1']
alpha = AlphaComplex(np.array(points))

alpha.plot_alpha()

# %% [markdown]
# ### Ejemplo 2

# %%
points = json.load(open(CLOUD_PATH))['alpha2']
alpha = AlphaComplex(np.array(points))

alpha.plot_alpha()

# %% [markdown]
# ### Ejemplo 3

# %%
points = json.load(open(CLOUD_PATH))['alpha3']
alpha = AlphaComplex(np.array(points))

alpha.plot_alpha()

# %% [markdown]
# ### Ejemplo 4

# %%
points = json.load(open(CLOUD_PATH))['alpha4']
alpha = AlphaComplex(np.array(points))

alpha.plot_alpha()

# %% [markdown]
# ### Ejemplo 5

# %%
points = np.random.rand(50,2)
alpha = AlphaComplex(points)
alpha.plot_alpha()

# %% [markdown]
# ### Ejemplo 6 - Anillo

# %%
points = json.load(open(CLOUD_PATH))['ring']
alpha = AlphaComplex(np.array(noise(points)))

alpha.plot_alpha()

# %% [markdown]
# ### Ejemplo 7 - Figura ocho

# %%
points = json.load(open(CLOUD_PATH))['eight']
alpha = AlphaComplex(np.array(noise(points)))

alpha.plot_alpha()

# %% [markdown]
# ### Ejemplo 8 - Rosa 3 Petalos

# %%
points = json.load(open(CLOUD_PATH))['3-petal']
alpha = AlphaComplex(np.array(noise(points)))

alpha.plot_alpha()
